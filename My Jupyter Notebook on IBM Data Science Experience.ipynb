# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Diego Garcia**
# Senior Associate

# %% [markdown]
# _"I would like to learn more about data science to gain new skills to apply them into my line of work"_

# %% [markdown]
# ### My code will show the result of a division

# %%
32/8
# Out:
# 4.0

# %% [markdown]
# <img scr=1000px-IBM_logo.svg.png>

# %% [markdown]
# ![1000px-IBM_logo.svg.png](attachment:1000px-IBM_logo.svg.png)
# ![Slide1CoverArt.jpg](attachment:Slide1CoverArt.jpg)
# ![0_FSm3GZEOmBWA8k-4.jpg](attachment:0_FSm3GZEOmBWA8k-4.jpg)
#
# 1. Data science
# 2. Python
# 3. Visualization
#
# Data science tools introduction:
# *  Python coding introduction
# *  Tableau introduction
# *  Dashboarding

# %% [markdown]
# <img scr=https://diylogodesigns.com/wp-content/uploads/2016/04/ibm-logo-png-transparent-background.png >

# %% [markdown]
# <img scr=https://diylogodesigns.com/wp-content/uploads/2016/04/ibm-logo-png-transparent-background.png />
